# %% [markdown]
# # Step 1:
#
# http://gnrd.globalnames.org/name_finder.html?token=7nmhv2arhp

# %%
import requests
import pandas as pd
import time

# %%
class Name_finder:
    '''
    http://gnrd.globalnames.org/api
    '''

    def __init__(self, document_url, max_seconds=60):
        root_url = 'http://gnrd.globalnames.org/name_finder.json'
        url = '{}?url={}&unique=true&data_source_ids=11'.format(root_url, document_url)
        res = requests.get(url).json()
        self.token_url = res['token_url']

        for s in range(1, max_seconds+1):
            time.sleep(1)
            print('Polling at {} seconds.'.format(s))
            self.json = requests.get(self.token_url).json()
            #print(self.json)
            if 'resolved_names' in self.json:
                print('FINISHED - resolved names returned in self.json["resolved_names"]')
                print('token url = {}'.format(self.token_url))
                break
                
# document_url = 'https://aubreymoore.github.io/crop-pest-list/list.html'
# x = Name_finder(document_url)

# %%
r = Name_finder('https://aubreymoore.github.io/crop-pest-list/list.html')
# Out:
# Polling at 1 seconds.
# Polling at 2 seconds.
# Polling at 3 seconds.
# Polling at 4 seconds.
# Polling at 5 seconds.
# Polling at 6 seconds.
# Polling at 7 seconds.
# Polling at 8 seconds.
# Polling at 9 seconds.
# Polling at 10 seconds.
# FINISHED - resolved names returned in self.json
# token url = http://gnrd.globalnames.org/name_finder.json?token=2olsab2rmp

# %%
taxa = r.json['resolved_names']
taxa[:2]
# Out:
# [{u'is_known_name': True,
#   u'results': [{u'canonical_form': u'Agave sisalana',
#     u'classification_path': u'Plantae|Tracheophyta|Liliopsida|Asparagales|Asparagaceae|Agave|Agave sisalana',
#     u'classification_path_ids': u'6|7707728|196|1169|7683|2766430|2766636',
#     u'classification_path_ranks': u'kingdom|phylum|class|order|family|genus|species',
#     u'data_source_id': 11,
#     u'data_source_title': u'GBIF Backbone Taxonomy',
#     u'edit_distance': 0,
#     u'gni_uuid': u'b2a8b282-f846-557e-8f96-aaa26d068cb5',
#     u'imported_at': u'2016-11-13T19:37:29Z',
#     u'match_type': 2,
#     u'match_value': u'Exact match by canonical form',
#     u'name_string': u'Agave sisalana Perrine',
#     u'prescore': u'3|0|0',
#     u'score': 0.988,
#     u'taxon_id': u'2766636'},
#    {u'canonical_form': u'Agave sisalana',
#     u'classification_path': u'Plantae|Tracheophyta|Liliopsida|Asparagales|Asparagaceae|Agave|Agave sisalana',
#     u'classification_path_ids': u'6|7707728|196|1169|7683|2766430|8123118',
#     u'classification_path_ranks': u'kingdom|phylum|class|order|family|genus|species',
#     u'data_source_id': 11,
#     u'data_source_title': u'GBIF Backbone Taxonomy',
#     u'edit_distance': 0,
#     u'gni_uuid': u'c2deb93a-de0e-58cf-bfeb-6fd196652038',
#     u'imported_at': u'2016-11-13T19:37:47Z',
#     u'match_type': 2,
#     u'match_value': u'Exact match by canonical form',
#     u'name_string': u'Agave sisalana Perrine ex Engelm.',
#     u'prescore': u'3|0|0',
#     u'score': 0.988,
#     u'taxon_id': u'8123118'}],
#   u'supplied_name_string': u'Agave sisalana'},
#  {u'is_known_name': False, u'supplied_name_string': u'Avocado'}]

# %%
mylist = []
for t in taxa:
    mydict = {'supplied_name_string': t['supplied_name_string'], 
              'is_known_name': t['is_known_name']}
    if t['is_known_name']:
        mydict['taxon_id'] = t['results'][0]['taxon_id']
    mylist.append(mydict)
mylist 
df = pd.DataFrame(mylist).sort_values('supplied_name_string')
df
# Out:
#     is_known_name            supplied_name_string taxon_id
# 28           True          Abelmoschus esculentus  3152707
# 377         False  Abelmoschus esculentus chinese      NaN
# 336          True             Abgrallaspis palmae  2083915
# 267          True     Acanthograeffea denticulata  1412321
# 270          True         Acanthograeffea modesta  1412323
# 128         False                           Acari      NaN
# 286          True                   Achaea janata  5113950
# 202          True                  Aclees porosus  1188297
# 125          True                       Acrididae     9394
# 165          True                     Acrocercops  1750759
# 92           True                Adoretus sinicus  4293553
# 338          True          Adoxophyes fasciculana  1740443
# 164          True                Adoxophyes melia  1740496
# 322          True            Agathodes ostentalis  5127097
# 0            True                  Agave sisalana  2766636
# 196          True                       Agonoxena  1853137
# 265          True            Agonoxena pyrogramma  1853138
# 197          True                    Agonoxenidae     4539
# 328         False             Agrilus occipitalis      NaN
# 169          True               Agrius convolvuli  1861644
# 134          True                     Agromyzidae     3329
# 361          True     Aiolopus thalassinus dubius  6255622
# 299          True               Alciphron glaucus  4782385
# 244          True        Aleurocanthus palauensis  8354964
# 331          True        Aleurocanthus spiniferus  2012158
# 245          True           Aleurodicus dispersus  2012122
# 276          True     Aleurodothrips fasciapennis  1420197
# 315          True         Aleurothrixus floccosus  2012137
# 154          True                     Aleyrodidae     4304
# 29           True                     Allium cepa  2857697
# ..            ...                             ...      ...
# 77           True                    Thysanoptera     1228
# 236          True               Tiracola plagiata  1762657
# 161          True                     Tortricidae     5343
# 235          True              Toxoptera aurantii  2075867
# 54           True                       Trigonops  1225109
# 283         False               Trigonops hirsuta      NaN
# 284         False             Trigonops inusitata      NaN
# 469         False              Trigonops vulgaris      NaN
# 376          True                Trioza vitiensis  5153672
# 427         False           Trissodoris guamensis      NaN
# 241          True     Trochorhopalus strangulatus  1169308
# 413          True                   Tropiduchidae     2232
# 408          True       Turbinococcus pandanicola  2095026
# 442          True                Ugyops annulipes  8144750
# 329          True                   Unaspis citri  7911763
# 123          True                Valanga excavata  1707539
# 126          True             Valanga nigricornis  1707497
# 207          True             Vinsonia stellifera  5163542
# 212          True          Xenaleyrodes artocarpi  4771658
# 233          True           Xyleborus ferrugineus  5020459
# 59           True            Xyleborus fornicatus  5020341
# 272          True             Xyleborus morigerus  5020248
# 182          True             Xyleborus perforans  5019910
# 230          True               Xyleborus similis  5020065
# 224          True                   Yponomeutidae     8874
# 453          True               Zanchius fragilis  7747800
# 25           True                        Zea mays  5290052
# 345         False               Zea mays oriental      NaN
# 18           True             Zingiber officinale  2757280
# 310         False      Zingiber officinale banana      NaN
#
# [475 rows x 3 columns]
